# %%
import geopandas as gpd
from keplergl import KeplerGl

# %%
gdf = gpd.read_file(r"C:\Users\bruno\Documents\J3Q3-4 BEP\repositories\FINALDATASET3.shp")
gdf
# Out:
#                 name_x    fclass     osm_id      long       latt  cluster  \
# 0      The Hague Tower  building   37774391  4.324224  52.071575     3603
# 1                 None  building  267117842  4.324910  52.071850     3603
# 2                 None  building   58350937  4.319504  52.019770     1403
# 3                 None  building  253797461  4.320369  52.019398     1403
# 4                 None  building  427468640  4.321300  52.018973     1403
# ...                ...       ...        ...       ...        ...      ...
# 93480             None  building  766622131  4.382658  52.054053     3714
# 93481             None  building  697411648  4.381724  52.054196      600
# 93482             None  building  766622106  4.382214  52.054351      600
# 93483             None  building  745899409  4.218895  52.041474     4934
# 93484             None  building  745899513  4.218672  52.041785     4934
#
#          C_PTS      D_C_PTS  C_Super    D_C_Super  C_DoctorsI   D_C_Doctor  \
# ...

# %%
config = {
  "version": "v1",
  "config": {
    "visState": {
      "filters": [],
      "layers": [
        {
          "id": "65n92e",
          "type": "point",
          "config": {
            "dataId": "data_2",
            "label": "data_2",
            "color": [
              255,
              153,
              31
            ],
            "columns": {
              "lat": "latt",
              "lng": "long",
              "altitude": "accs"
            },
            "isVisible": True,
            "visConfig": {
              "radius": 4,
              "fixedRadius": False,
              "opacity": 0.8,
              "outline": False,
              "thickness": 0.5,
              "strokeColor": [
                225,
                49,
                106
              ],
              "colorRange": {
                "name": "UberPool 6",
                "type": "diverging",
                "category": "Uber",
                "colors": [
                  "#213E9A",
                  "#551EAD",
                  "#C019BD",
                  "#D31256",
                  "#E6470A",
                  "#F9E200"
                ]
              },
              "strokeColorRange": {
                "name": "UberPool 6",
                "type": "diverging",
                "category": "Uber",
                "colors": [
                  "#213E9A",
                  "#551EAD",
                  "#C019BD",
                  "#D31256",
                  "#E6470A",
                  "#F9E200"
                ]
              },
              "radiusRange": [
                0,
                50
              ],
              "filled": True
            },
            "hidden": False,
            "textLabel": []
          },
          "visualChannels": {
            "colorField": {
              "name": "accs",
              "type": "integer"
            },
            "colorScale": "quantize",
            "strokeColorField": {
              "name": "accs",
              "type": "integer"
            },
            "strokeColorScale": "quantize",
            "sizeField": None,
            "sizeScale": "linear"
          }
        }
      ],
      "interactionConfig": {
        "tooltip": {
          "fieldsToShow": {
            "data_2": [
              "D_C_PTS",
              "D_C_Super",
              "D_C_Doctor",
              "D_C_School",
              "D_C_Sport",
              "accs"
            ]
          },
          "enabled": True
        },
        "brush": {
          "size": 0.5,
          "enabled": False
        },
        "geocoder": {
          "enabled": False
        },
        "coordinate": {
          "enabled": False
        }
      },
      "layerBlending": "normal",
      "splitMaps": [],
      "animationConfig": {
        "currentTime": None,
        "speed": 1
      }
    },
    "mapState": {
      "bearing": 0,
      "dragRotate": False,
      "latitude": 52.06007990791819,
      "longitude": 4.307741205732435,
      "pitch": 0,
      "zoom": 11.66246341000922,
      "isSplit": False
    },
    "mapStyle": {
      "styleType": "dark",
      "topLayerGroups": {},
      "visibleLayerGroups": {
        "label": True,
        "road": True,
        "border": False,
        "building": True,
        "water": True,
        "land": True,
        "3d building": False
      },
      "threeDBuildingColor": [
        9.665468314072013,
        17.18305478057247,
        31.1442867897876
      ],
      "mapStyles": {}
    }
  }
}

# %%
map_1 = KeplerGl()
map_1.add_data(data=gdf, name='data_2')
map_1.config = config
map_1
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter
# KeplerGl(config={'version': 'v1', 'config': {'visState': {'filters': [], 'layers': [{'id': '65n92e', 'type': '…

# %%
map_1.save_to_html(data={'data_2': gdf}, config=config, file_name='final_map.html')
# Out:
# Map saved to final_map.html!
